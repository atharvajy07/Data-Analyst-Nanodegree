# %% [markdown]
# ##### The follwoing report is a compilation of the analysis done by me as a part of the 'wrangle and analyze data' project of the DAND programme offered by 'UDACITY'.

# %% [markdown]
# # Overview:

# %% [markdown]
# ![dog%201.jpg](attachment:dog%201.jpg)

# %% [markdown]
# ### In this project we have analyzed the data about _'WeRateDogs'_ - a twitter account that rates the pictures/videos of your dogs. The have a fixed rating standard- The numerator of the rating is almost never less than 10 (Because they are DOGS!!!) and the denominator is always 10.The analysis of this dataset was carried after extensively wrangling the dataset(s).

# %% [markdown]
# # Analysis:

# %% [markdown]
# ## 1.

# %% [markdown]
# ## General analysis of the df_archive dataframe:

# %% [markdown]
# ![dog%202.jpg](attachment:dog%202.jpg)

# %% [markdown]
#  - __The average rating given out by the twitter account is 12.875.__
#  - __The minimum and maximum ratings are 10 and 1776 respectively.__

# %% [markdown]
# ## 2.
#
# ### General analysis of the df_pred dataframe:

# %% [markdown]
# ![dog%203.jpg](attachment:dog%203.jpg)

# %% [markdown]
# ![dog%204.JPG](attachment:dog%204.JPG)

# %% [markdown]
#  - __The model has the highest confidence on its first prediction.__
#  - __The lowest and highest confidence that the model has on its first prediction throughout the dataframe is 0.04 and 1 respectively.__
#  - __The lowest and highest confidence that the model has on its second prediction throughout the dataframe is 1.01e -8 and 0.488 respectively.__
#  - __The lowest and highest confidence that the model has on its third prediction throughout the dataframe is 1.74e-10 and 0.273 respectively.__
#  - __On average the model has 60% confidence on its first prediction.__
#  - __On average the model has 11.3% confidence on its second prediction.__
#  - __On average the model has 0.06% confidence on its third predicition.__

# %% [markdown]
# ## 3.

# %% [markdown]
# ### General analysis of the df_tweepy:

# %% [markdown]
# ![dog%205.JPG](attachment:dog%205.JPG)

# %% [markdown]
#  - __The minimum and maximum number of likes is 0 and 156164 respectively.__
#  - __The minimum and maximum number of retweets is 1 and 77780 respectively.__
#  - __The average number of likes for a tweet is 7554.39.__
#  - __The average number of retweets for a tweet is 2703.41__

# %% [markdown]
# ###                                         What is a like on twitter?
#
# ![dog%2011.JPG](attachment:dog%2011.JPG)

# %% [markdown]
# ### What is a retweet on twitter?
# ![dog%2012.JPG](attachment:dog%2012.JPG)

# %% [markdown]
# ## 4.
#
# ### Observing the spread of various columns in df_pred dataframe:

# %% [markdown]
# ![dog%207.png](attachment:dog%207.png)

# %% [markdown]
# - __The Confidence on prediction #1 column has a left skewed spread.__
# - __The rest of the histograms appear to be right-skewed.__
# - __Our predicting model has the highest confidence in its 1st prediction.__
# - __The confidence of the model goes on decreasing as the prediction number increases.__
# - __Majority of times, the first image is the correct image from all the images present on the respective webpage.__

# %% [markdown]
# ## 5.
#
# ### Observing the correlation between the confidence of the model on its various predictions:

# %% [markdown]
# ![dog%208.png](attachment:dog%208.png)

# %% [markdown]
#  - __There is a weak positive correlation between the confidence on first prediction and the image number.__
#  - __There is a very weak negative correlation between the image number and the confidence of the model on its second and third predictions.__
#  - __There is moderate negative correlation between the confidence on first and second predictions.__
#  - __There is weak negative correlation between the confidence on first on third predictions.__
#  - __There is moderate postitive correlation between the confidence on second and third predictions.__

# %% [markdown]
# ## 6.
#
# ### Observing the correlation between the number of likes and retweets that a tweet gets:

# %% [markdown]
# ![dog%209.png](attachment:dog%209.png)

# %% [markdown]
# - __There is extremely strong positive correlation between number of likes and retweet count for a tweet.__

# %% [markdown]
# ## 7. Proportion of correct predictions by the model.

# %% [markdown]
#  - __73.8% of the first predictions made by the model are correct.__
#  - __74.8% of the second predictions made by the model are correct.__
#  - __72.2% of the third predictions made by the model are correct.__

# %% [markdown]
# #### PS: In the df_pred dataframe, multiple predictions are true for a single entry because a particular dog can be a mix-breed and the model might have picked the breed with most dominant traits in the first prediction, the breed with lesser dominant traits in the second prediction and so on. That is the reason why the above percentages do not add up to 100.

# %% [markdown]
# # Conclusions:
#  - __As the number of likes on a tweet increases, the number of retweets increases and vice-versa.__
#  - __The second prediction of the model makes the highest percentage of correct predictions.__
#  - __Majority of the times, the model has the highest confidence on its first prediction.__

# %% [markdown]
# # Limitation of the analysis:
# ### Since we could not merge the three dataframes into one, we could not analyze some relationships like 'number of likes and ratings', ' number of retweets and ratings'.
